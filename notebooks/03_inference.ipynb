# %%
import sys
import os
sys.path.insert(0, '/Users/jennifercyc/Desktop/HSH/ML Project/fraud-detector/src')
from inference import predict_new_data

import pandas as pd

# %%
input_file = "Worksheet in Case Study question 2.xlsx"

# %%
results = predict_new_data(input_file)
# Out:
# ✅ Predictions saved to: /Users/jennifercyc/Desktop/HSH/ML Project/fraud-detector/data/predictions.csv

# %%
results[['fraud_predicted']].value_counts()
# Out:
# fraud_predicted
# 0                  752
# 1                  247
# Name: count, dtype: int64

# %%
pd.read_csv("/Users/jennifercyc/Desktop/HSH/ML Project/fraud-detector/data/predictions.csv").head()
# Out:
#    months_as_customer  age  policy_number policy_state policy_csl  \
# 0                 328   48         521585           oh    250/500
# 1                 228   42         342868           in    250/500
# 2                 176   29         687698           oh    100/300
# 3                 299   41         227811           il    250/500
# 4                 228   44         367455           il   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit insured_sex  \
# 0             1000.0                1406.91             0.0        male
# 1             2000.0                1197.22       5000000.0        male
# 2             2000.0                1413.14       5000000.0      female
# 3             2000.0                1415.74       6000000.0      female
# 4             1000.0                1583.91       6000000.0        male
#
#   insured_education_level  ... property_claim vehicle_claim  auto_make  \
# ...
